# %%
import workdays
from datetime import datetime, timedelta, date
from dateutil.relativedelta import relativedelta
import calendar
import pdblp
from xbbg import blp
import pandas as pd
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] = 'Meiryo'

def BDP(T):
    T = [x + " Index" for x in T]
    F = ["name","security_name","name_kanji","px_last","indx_freq","indx_units","quote_units","crncy","last_update_dt","long_comp_name"]
    df = blp.bdp(tickers=T, flds=F).loc[T,:].reset_index()
    return df

def BDH(T,d_from,d_to):
    T1 = [x + " Index" for x in T]
    df = blp.bdh(T1, "px_last", d_from, d_to).reset_index()
    df = df[["index"]+T1]
    df.columns = ["Date"] + T
    df["Date"] = pd.to_datetime(df["Date"])
    return df

def BDH_List(T,i,Survey=0):
    d_to = workdays.workday(date.today(), days=0)
    d_from = d_to - relativedelta(months=i)
    T1 = [x + " Index" for x in T]
    df = blp.bdh(T1, "px_last", d_from, d_to).reset_index()
    df = df[["index"]+T1]
    df.columns = ["Date"] + T
    df["Date"] = pd.to_datetime(df["Date"])
    tmp = df.T.copy()
    tmp.columns = [date.astype('datetime64[M]').astype(str).replace('-', '/').replace('20', '') for date in df["Date"].values]
    tmp = tmp.iloc[1:,-i:].iloc[:, ::-1]
    tmp.index = df_BDP["security_name"].values
    
    if Survey == 1:
        tmp.insert(0, "Survey", "")
        d_from = d_to - relativedelta(months=1)
        df = blp.bdh(T1, "bn_survey_median", d_from, d_to)
        df.columns = df.columns.get_level_values(0)

        for j in df.columns:
            tmp.iloc[T1.index(j),0] = df[j][0]
    
    return tmp

def Plot(title="",c="",l="",axhline="",m="", ymin=None, ymax=None):
    fig, ax = plt.subplots(figsize=(6.5, 2))
    ax.plot(df["Date"], df[c], label=l, marker=m)
    ax.set_title(title, fontsize=10)
    if axhline != "":
        ax.axhline(y=axhline, color='gray', linestyle='--', linewidth=0.5)
    if l != "":
        ax.legend(loc='best')
    if ymin is not None and ymax is not None:
        ax.set_ylim(ymin, ymax)
    plt.tight_layout()
    plt.show()
    
        
def Plot2(title,c1,c2,l1,l2,m1="",m2="",axhline="",color2='tab:orange'): #Two-axis graph  
    fig, ax = plt.subplots(figsize=(6.5, 2))
    ax.plot(df["Date"], df[c1], marker=m1, label=l1)
    ax.plot(df["Date"], df[c2], marker=m2, label=l2, color=color2)
    if axhline != "":
        ax.axhline(y=axhline, color='gray', linestyle='--', linewidth=0.5)
    ax.set_title(title, fontsize=10)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()
    
def PlotTW(title,c1,c2,l1,l2): #Two-axis graph
    fig, ax = plt.subplots(figsize=(6.5, 2.3))
    
    line1, = ax.plot(df["Date"], df[c1], label=l1)  # line1オブジェクトを取得
    ax.set_ylabel(l1)

    ax2 = ax.twinx()
    line2, = ax2.plot(df["Date"], df[c2], label=l2, color='lightsteelblue')  # line2オブジェクトを取得
    ax2.set_ylabel(l2)

    ax.set_title(title, fontsize=10)
    
    # ax.legend(handles=[line1, line2], labels=[l1, l2], loc='center left', bbox_to_anchor=(1.09, 0.5))
    # ax.legend(handles=[line1, line2], labels=[l1, l2], loc='upper center', bbox_to_anchor=(0.5, -0.2))
    ax.legend(handles=[line1, line2], labels=[l1, l2], loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)

    plt.tight_layout()
    plt.show()
    
    
def Plotv(title, T, L, axhline=""):
    fig, ax = plt.subplots(figsize=(7.5, 2))
    for i, t in enumerate(T):
        ax.plot(df["Date"], df[t], label=L[i], linewidth=0.5 if t != T[0] else 1.5)

    # Set x-axis to show 12 data points
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

    if axhline != "":
        ax.axhline(y=axhline, color='gray', linestyle='--', linewidth=0.5)
    
    ax.set_title(title, fontsize=10)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.xticks(rotation=0)  # x軸のラベルを水平に設定
    plt.tight_layout()
    plt.show()


def term():
    tmp = df["Date"][0].strftime("%Y-%m")
    tmp += "～"
    tmp += df["Date"][len(df)-1].strftime("%Y-%m")
    return tmp

# %% [markdown]
# ## US
# #### ISM Manufacturing

# %%
T = ["NAPMPMI","NAPMPRIC","NAPMPROD","NAPMNEWO","NAPMBACK","NAPMSUPL","NAPMINV","NAPMCINV","NAPMEMPL","NAPMEXPT","NAPMIMPT"]   
df_BDP = BDP(T)
BDH_List(T,13,1)
# Out:
#                Survey 23/12 23/11 23/10 23/09 23/08 23/07 23/06 23/05 23/04  \
# ISM PMI          47.1  47.4  46.7  46.7  49.0  47.6  46.4  46.0  46.9  47.1
# Prices paid      49.5  45.2  49.9  45.1  43.8  48.4  42.6  41.8  44.2  53.2
# Production             50.3  48.5  50.4  52.5  50.0  48.3  46.7  51.1  48.9
# New orders       49.1  47.1  48.3  45.5  49.2  46.8  47.3  45.6  42.6  45.7
# Backlog orders         45.3  39.3  42.2  42.4  44.1  42.8  38.7  37.5  43.1
# Supplier               47.0  46.2  47.7  46.4  48.6  46.1  45.7  43.5  44.6
# Inventories            44.3  44.8  43.3  45.8  44.0  46.1  44.0  45.8  46.3
# Inv                    48.1  50.8  48.6  47.1  48.7  48.7  46.2  51.4  51.3
# Employment       46.5  48.1  45.8  46.8  51.2  48.5  44.4  48.1  51.4  50.2
# Export orders          49.9  46.0  49.4  47.4  46.5  46.2  47.3  50.0  49.8
# Imports                46.4  46.2  47.9  48.2  48.0  49.6  49.3  47.3  49.9
#
#                23/03 23/02 23/01 22/12
# ISM PMI         46.3  47.7  47.4  48.4
# Prices paid     49.2  51.3  44.5  39.4
# Production      47.8  47.3  48.0  48.6
# New orders      44.3  47.0  42.5  45.1
# Backlog orders  43.9  45.1  43.4  41.4
# Supplier        44.8  45.2  45.6  45.1
# Inventories     47.5  50.1  50.2  52.3
# Inv             48.9  46.9  47.4  48.2
# Employment      46.9  49.1  50.6  50.8
# Export orders   47.6  49.9  49.4  46.2
# Imports         47.9  49.9  47.8  45.1

# %%
def BDH_List(T,i,Survey=0):
    d_to = workdays.workday(date.today(), days=0)
    d_from = d_to - relativedelta(months=i)
    T1 = [x + " Index" for x in T]
    df = blp.bdh(T1, "px_last", d_from, d_to).reset_index()
    df = df[["index"]+T1]
    df.columns = ["Date"] + T
    df["Date"] = pd.to_datetime(df["Date"])
    tmp = df.T.copy()
    tmp.columns = [date.astype('datetime64[M]').astype(str).replace('-', '/').replace('20', '') for date in df["Date"].values]
    tmp = tmp.iloc[1:,-i:].iloc[:, ::-1]
    tmp.index = df_BDP["security_name"].values
    
    if Survey == 1:
        tmp.insert(0, "Survey", "-")
        df = blp.bdp(tickers=T1, flds="bn_survey_median")    
        for j in range(len(df)):
            tmp.iloc[T1.index(df.index[j]),0] = df.iloc[j,0]
    
    return tmp

T = ["NAPMPMI","NAPMPRIC","NAPMPROD","NAPMNEWO","NAPMBACK","NAPMSUPL","NAPMINV","NAPMCINV","NAPMEMPL","NAPMEXPT","NAPMIMPT"]   
df_BDP = BDP(T)
BDH_List(T,13,1)
# Out:
#                Survey 23/12 23/11 23/10 23/09 23/08 23/07 23/06 23/05 23/04  \
# ISM PMI          47.0  47.4  46.7  46.7  49.0  47.6  46.4  46.0  46.9  47.1
# Prices paid      45.8  45.2  49.9  45.1  43.8  48.4  42.6  41.8  44.2  53.2
# Production          -  50.3  48.5  50.4  52.5  50.0  48.3  46.7  51.1  48.9
# New orders          -  47.1  48.3  45.5  49.2  46.8  47.3  45.6  42.6  45.7
# Backlog orders      -  45.3  39.3  42.2  42.4  44.1  42.8  38.7  37.5  43.1
# Supplier            -  47.0  46.2  47.7  46.4  48.6  46.1  45.7  43.5  44.6
# Inventories         -  44.3  44.8  43.3  45.8  44.0  46.1  44.0  45.8  46.3
# Inv                 -  48.1  50.8  48.6  47.1  48.7  48.7  46.2  51.4  51.3
# Employment          -  48.1  45.8  46.8  51.2  48.5  44.4  48.1  51.4  50.2
# Export orders       -  49.9  46.0  49.4  47.4  46.5  46.2  47.3  50.0  49.8
# Imports             -  46.4  46.2  47.9  48.2  48.0  49.6  49.3  47.3  49.9
#
#                23/03 23/02 23/01 22/12
# ISM PMI         46.3  47.7  47.4  48.4
# Prices paid     49.2  51.3  44.5  39.4
# Production      47.8  47.3  48.0  48.6
# New orders      44.3  47.0  42.5  45.1
# Backlog orders  43.9  45.1  43.4  41.4
# Supplier        44.8  45.2  45.6  45.1
# Inventories     47.5  50.1  50.2  52.3
# Inv             48.9  46.9  47.4  48.2
# Employment      46.9  49.1  50.6  50.8
# Export orders   47.6  49.9  49.4  46.2
# Imports         47.9  49.9  47.8  45.1

# %%
T = ["NAPMPMI","NAPMNMI"] 
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=120)
d_from = "20060101"
df = BDH(T,d_from,d_to)

print(term())
Plot("ISM_製造業","NAPMPMI","",50,"")
Plot("ISM_サービス","NAPMNMI","",50,"")

plt.tight_layout()
plt.show()
# Out:
# 2006-01～2023-12

# %%
T = ["NAPMPMI","JPMIINDU","PMITMEZ","MPMICNMA"]
L = ["US_ISM","Global","ユーロ圏","中国"]
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=36)
df = BDH(T,d_from,d_to)
print(term())
Plotv("ISM_製造業 vs各国PMI",T,L,50)

T = ["NAPMNMI","JPMISERV","PMITSEZ","MPMICNSA"]
L = ["US_ISM","Global","ユーロ圏","中国"]
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=36)
df = BDH(T,d_from,d_to)
Plotv("ISM_サービス vs各国PMI",T,L,50)
# Out:
# 2021-01～2023-12

# %%
T = ["NAPMPMI","NAPMNEWO","NAPMINV"] 
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=120)
df = BDH(T,d_from,d_to)

df["diff"] = df["NAPMNEWO"] - df["NAPMINV"] 
df["diff_ave"] = df["diff"].rolling(window=3).mean()
df["ratio"] = df["NAPMNEWO"] / df["NAPMINV"] 

print(term())
Plot2('ISM製: 新規受注 - 在庫',"diff","diff_ave",'新規受注-在庫',"3ヵ月平均","","",0) #lightsteelblue"
Plot("ISM製: 総合ビジネス 景況指数","NAPMPMI","ISM製: 総合ビジネス 景況指数",50,"")
Plot2("ISM製: 新規受注、在庫","NAPMNEWO","NAPMINV","新規受注","在庫","","",50)

plt.tight_layout()
plt.show()
df_BDP = BDP(T)
df_BDP
# Out:
# 2014-01～2023-12
#             index                            name security_name  \
# 0   NAPMPMI Index        ISM Manufacturing PMI SA       ISM PMI
# 1  NAPMNEWO Index  ISM Manufacturing Report on Bu    New orders
# 2   NAPMINV Index  ISM Manufacturing Report on Bu   Inventories
#
#            name_kanji px_last indx_freq indx_units quote_units last_update_dt  \
# 0  米ISM製造業景況指数(PMI)SA    47.4   Monthly      Value        S.A.     2023-12-31
# 1     米ISM製造業新規受注指数SA    47.1   Monthly      Value         NaN     2023-12-31
# 2     全米供給管理協会景気指数 在庫    44.3   Monthly      Value         NaN     2023-12-31
#
#                                       long_comp_name
# 0                           ISM Manufacturing PMI SA
# 1  ISM Manufacturing Report on Business New Order...
# 2  ISM Manufacturing Report on Business Inventori...

# %%
T = ["NAPMPMI","TWEOTTLY"]    
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=150)
df = BDH(T,d_from,d_to)
print(term())
PlotTW('ISM製 vs 台湾輸出 YoY',"NAPMPMI","TWEOTTLY",'ISM製','台湾輸出 YoY')
df_BDP = BDP(T)
df_BDP
# Out:
# 2011-07～2023-12
#             index                           name security_name  \
# 0   NAPMPMI Index       ISM Manufacturing PMI SA       ISM PMI
# 1  TWEOTTLY Index  MOEA Taiwan Export Orders YoY           YoY
#
#            name_kanji px_last indx_freq indx_units quote_units last_update_dt  \
# 0  米ISM製造業景況指数(PMI)SA    47.4   Monthly      Value        S.A.     2023-12-31
# 1     MOEA台湾輸出受注(前年比)  -16.02   Monthly       Rate    % CHANGE     2023-12-31
#
#                   long_comp_name
# 0       ISM Manufacturing PMI SA
# 1  MOEA Taiwan Export Orders YoY

# %%
T = ["NAPMPRIC","NAPMNPRC","FDIUFDYO","FDIUSGYO"]
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=12*5)
df = BDH(T,d_from,d_to)
# Plot("ISM製: 仕入れ価格","NAPMPRIC","",50)
# Plot("ISM製: 仕入れ価格","NAPMNPRC","",50)
print(term())
Plot2('ISM: 価格指数',"NAPMPRIC","NAPMNPRC",'製造業',"サービス","","",50,"lightsteelblue")
Plot2('PPI YoY',"FDIUFDYO",'FDIUSGYO',"PPI","exFoods,Energy","","",0,"lightsteelblue")
# Plot("PPI YoY","FDIUFDYO","",0)
# Plot("PPI exFoods,Energy YoY","FDIUSGYO","")
# Plot("PPI YoY","FDIUFDYO","",0)
df_BDP = BDP(T)
df_BDP
# Out:
# 2019-01～2023-12
#             index                            name          security_name  \
# 0  NAPMPRIC Index  ISM Manufacturing Report on Bu            Prices paid
# 1  NAPMNPRC Index  ISM Services PMI Report on Bus            Prices paid
# 2  FDIUFDYO Index     US PPI Final Demand YoY NSA           Final Demand
# 3  FDIUSGYO Index  US PPI Final Demand Less Foods  Less Foods and Energy
#
#               name_kanji px_last indx_freq indx_units last_update_dt  \
# 0         米ISM製造業価格指数NSA    45.2   Monthly      Value     2023-12-31
# 1         米ISM非製造業価格指数SA    57.4   Monthly      Value     2023-12-31
# 2     米 PPI最終需要(前年比､季調前)     1.0   Monthly      Value     2023-12-31
# 3  米 PPI最終需要(除食品･ｴﾈﾙｷﾞｰ､     1.8   Monthly      Value     2023-12-31
#
#                                       long_comp_name quote_units
# 0  ISM Manufacturing Report on Business Prices In...         NaN
# 1      ISM Services PMI Report on Business Prices SA         NaN
# 2                        US PPI Final Demand YoY NSA    2009=100
# 3  US PPI Final Demand Less Foods and Energy YoY NSA    2009=100

# %% [markdown]
# ### ISM Services

# %%
T = ["NAPMNMI","NAPMNMAN","NAPMNPRC","NAPMNNO","NAPMNBO","NAPMNSD","NAPMNIC","NAPMNIS","NAPMNEMP","NAPMNNEO","NAPMNIMP"]   
df_BDP = BDP(T)
df_BDP
BDH_List(T,13,1)
# Out:
#                     Survey 23/12 23/11 23/10 23/09 23/08 23/07 23/06 23/05  \
# Services PMI          51.7  50.6  52.7  51.8  53.6  54.5  52.7  53.9  50.3
# Business activity        -  56.6  55.1  54.1  58.8  57.3  57.1  59.2  51.5
# Prices paid              -  57.4  58.3  58.6  58.9  58.9  56.8  54.1  56.2
# New orders               -  52.8  55.5  55.5  51.8  57.5  55.0  55.5  52.9
# Back orders              -  49.4  49.1  50.9  48.6  41.8  52.1  43.9  40.9
# Deliveries               -  49.5  49.6  47.5  50.4  48.5  48.1  47.6  47.7
# Inventory change         -  49.6  55.4  49.5  54.2  57.7  50.4  55.9  58.3
# Inventory sentiment      -  55.3  62.2  54.4  54.8  61.5  56.6  54.0  61.0
# Employment               -  43.3  50.7  50.2  53.4  54.7  50.7  53.1  49.2
# Export orders            -  50.4  53.6  48.8  63.7  62.1  61.1  61.5  59.0
# Imports                  -  49.3  53.7  60.0  50.6  52.3  52.3  54.6  50.0
#
#                     23/04 23/03 23/02 23/01 22/12
# Services PMI         51.9  51.2  55.1  55.2  49.2
# Business activity    52.0  55.4  56.3  60.4  53.5
# Prices paid          59.6  59.5  65.6  67.8  68.1
# New orders           56.1  52.2  62.6  60.4  45.2
# Back orders          49.7  48.5  52.8  52.9  51.5
# Deliveries           48.6  45.8  47.6  50.0  48.5
# Inventory change     47.2  52.8  50.6  49.2  45.1
# Inventory sentiment  48.9  57.9  55.3  55.8  55.9
# Employment           50.8  51.3  54.0  50.0  49.4
# Export orders        60.9  43.7  61.7  59.0  47.7
# Imports              51.3  43.6  52.6  53.0  52.7

# %%
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=250)
df = BDH(T,d_from,d_to)
print(term())
Plot("ISM Service","NAPMNMI","",50,"")
Plot2("Inventory","NAPMNIC","NAPMNIS","Inventory change","Inventory sentiment","","",50)
# Out:
# 2003-03～2023-12

# %%
T = ["NAPMNMI","NAPMNNO","NAPMNIC","NAPMNIS"] 
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=120)
df = BDH(T,d_from,d_to)

df["diff"] = df["NAPMNNO"] - df["NAPMNIC"] 
df["diff_ave"] = df["diff"].rolling(window=3).mean()

df["diff2"] = df["NAPMNNO"] - df["NAPMNIS"] 
df["diff_ave2"] = df["diff"].rolling(window=3).mean()

print(term())
Plot2('ISM製: 新規受注 - 在庫',"diff","diff_ave",'新規受注-在庫',"3ヵ月平均","","",0) #lightsteelblue"
Plot("ISM製: 総合ビジネス 景況指数","NAPMNMI","ISM製: 総合ビジネス 景況指数",50,"")
Plot2('ISM製: 新規受注 - 在庫',"diff2","diff_ave2",'新規受注-在庫',"3ヵ月平均","","",0) #lightsteelblue"

plt.tight_layout()
plt.show()
df_BDP = BDP(T)
df_BDP
# Out:
# 2014-01～2023-12
#            index                            name        security_name  \
# 0  NAPMNMI Index                ISM Services PMI         Services PMI
# 1  NAPMNNO Index  ISM Services PMI Report on Bus           New orders
# 2  NAPMNIC Index  ISM Services PMI Report on Bus     Inventory change
# 3  NAPMNIS Index  ISM Services PMI Report on Bus  Inventory sentiment
#
#           name_kanji px_last indx_freq indx_units last_update_dt  \
# 0  米ISM非製造業景況指数(NMI)    50.6   Monthly      Value     2023-12-31
# 1   米ISM非製造業新規受注指数SA    52.8   Monthly      Value     2023-12-31
# 2    全米供給管理協会景気指数 非製    49.6   Monthly      Value     2023-12-31
# 3    全米供給管理協会景気指数 非製    55.3   Monthly      Value     2023-12-31
#
#                                       long_comp_name
# 0                                   ISM Services PMI
# 1  ISM Services PMI Report on Business New Orders SA
# 2  ISM Services PMI Report on Business Inventorie...
# 3  ISM Services PMI Report on Business Inventory ...

# %%
T = ["NAPMPMI","GDP CYOY"]    
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=450)
df = BDH(T,d_from,d_to)
df.fillna(method="ffill", inplace=True)

print(term())
PlotTW('ISMサ vs GDP YoY',"NAPMPMI","GDP CYOY",'ISMサ','GDP')
# Out:
# 1986-07～2023-12

# %% [markdown]
# ### Durable Order

# %%
T = ["DGNOXYOY","DGNOCHNG","DGNOXTCH","CGNOXAI%"]
d_from = d_to - relativedelta(months=12*3)
d_to = workdays.workday(date.today(), days=0)
df = BDH(T,d_from,d_to)

print(term())
Plot("耐久財受注ex輸送機 YoY","DGNOXYOY","",0)
Plot("耐久財受注 MoM","DGNOCHNG","",0)
Plot("耐久財受注ex輸送機 MoM","DGNOXTCH","",0)

df_BDP = BDP(T)
df_BDP
# Out:
# 2021-01～2023-12
#             index                            name  \
# 0  DGNOXYOY Index  US Durable Goods New Orders To
# 1  DGNOCHNG Index  US Durable Goods New Orders In
# 2  DGNOXTCH Index  US Durable Goods New Orders To
# 3  CGNOXAI% Index  Capital Goods New Orders Nonde
#
#                     security_name                      name_kanji px_last  \
# 0  Drable Gds ex Transport YOY SA  US Durable Goods New Orders To    2.34
# 1                  Month % change              米製造業受注MoM%-耐久財 季調値     0.0
# 2                    Less Trans %              米製造業受注MoM%-耐久財(除輸送     0.6
# 3                 Less aircraft %              米製造業受注MoM%-資本財(除航空     0.3
#
#   indx_freq indx_units quote_units last_update_dt  \
# 0   Monthly    Percent           %     2023-12-31
# 1   Monthly       Rate    % CHANGE     2023-12-31
# 2   Monthly       Rate    % CHANGE     2023-12-31
# 3   Monthly       Rate    % CHANGE     2023-12-31
#
#                                       long_comp_name
# 0  US Durable Goods New Orders Total ex Transport...
# 1      US Durable Goods New Orders Industries MoM SA
# 2  US Durable Goods New Orders Total ex Transport...
# 3  Capital Goods New Orders Nondefense Ex Aircraf...

# %%
T = ["SPXT","XNDX","RU20INTR","KRXTR"] 
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=120)
d_from = "20070103"
df = BDH(T,d_from,d_to)
tmp = df["RU20INTR"] / df["SPXT"] 
df["Russel2000/SP500"] = tmp / tmp[0] * 100
tmp = df["XNDX"] / df["SPXT"]
df["Nasdaq/SP500"] = tmp / tmp[0] * 100

tmp = df["KRXTR"]/ df["SPXT"]
df["KRXTR/SP500"] = tmp / tmp[0] * 100

print(term())
Plot("SP500","SPXT","")
Plot("ハイテク企業の躍進 (Nasdaq/SP500*100)","Nasdaq/SP500","")
Plot("中小企業 vs 大企業 (Russel2000/SP500 *100)","Russel2000/SP500","")
Plot("大企業 vs 中小企業 (Russel2000/SP500 *100)","Russel2000/SP500","")
# Out:
# 2007-01～2024-01

# %%
T = ["SPXT","XNDX","RU20INTR","KRXTR"] 
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=120)
d_from = "20070103"
df = BDH(T,d_from,d_to)
tmp = df["RU20INTR"] / df["SPXT"] 
df["Russel2000/SP500"] = tmp / tmp[0] * 100
tmp = df["XNDX"] / df["SPXT"]
df["Nasdaq/SP500"] = tmp / tmp[0] * 100

tmp = df["KRXTR"]/ df["SPXT"]
df["KRXTR/SP500"] = tmp / tmp[0] * 100

print(term())
Plot("SP500","SPXT","")
Plot("ハイテク企業の躍進 (Nasdaq/SP500)","Nasdaq/SP500","")
Plot("中小企業 vs 大企業 (Russel2000/SP500)","Russel2000/SP500","")
Plot("ReginalBank vs SP500 (KRXTR/SP500)","KRXTR/SP500","")
# Out:
# 2007-01～2024-01

# %% [markdown]
# ### SLOOS

# %%
#SLOOS
T = ["SLDETIGT","SLDETGTS","SLDESPRD","SLDESPDS","SLDEDEMD","SLDEDEMS"]
df_BDP = BDP(T)

d_from = "20000101"
d_to = workdays.workday(date.today(), days=0)
df = BDH(T,d_from,d_to)
print(term())
Plot("大中企業向貸出態度(四半期、高いほど厳しい)/SLDETIGT","SLDETIGT","",0)
Plot("小企業向貸出態度/SLDETGTS","SLDETGTS","",0)

Plot("大中企業ローン需要/SLDEDEMD","SLDEDEMD","",0)
Plot("小企業ローン需要/SLDEDEMS","SLDEDEMS","",0)


# https://jp.reuters.com/markets/japan/funds/SBPCSWNC6ZMALBKIDZE5MSXF5I-2023-11-06/
df_BDP
# Out:
# 2000-01～2023-10
#             index                            name  \
# 0  SLDETIGT Index   Net % of Domestic Respondents
# 1  SLDETGTS Index   Net % of Domestic Respondents
# 2  SLDESPRD Index  Net % of Dom Respond Inc Sprea
# 3  SLDESPDS Index   Net % of Domestic Respondents
# 4  SLDEDEMD Index  Net % of Dom Respond Reporting
# 5  SLDEDEMS Index   Net % of Domestic Respondents
#
#                     security_name           name_kanji px_last indx_freq  \
# 0       Sup/Dem C&I LoanTight L/M    大･中企業向け商工業ﾛｰﾝの基準を    33.9   Monthly
# 1  Net % C&I Loans Tight Stands S     小企業向け商工業ﾛｰﾝの基準を厳    30.4   Monthly
# 2         Sup/Dem C&I LoanSpreads  大･中企業向け貸し出しｽﾌﾟﾚｯﾄﾞを    50.0   Monthly
# 3  Net % COF Spread Loan Rates Sm  大･中企業向け貸し出しｽﾌﾟﾚｯﾄﾞを    44.6   Monthly
# 4          Sup/Dem C&I LoanDemand    大･中企業向け商工業ﾛｰﾝの需要増   -30.5   Monthly
# 5  Net % Strong Demd C&I  Loans S     小企業向け商工業ﾛｰﾝの需要増加   -49.1   Monthly
#
#   indx_units quote_units crncy last_update_dt  \
# 0       Rate     % RATIO   USD     2023-10-31
# 1       Rate     % RATIO   NaN     2023-10-31
# 2       Rate     % RATIO   USD     2023-10-31
# 3       Rate     % RATIO   NaN     2023-10-31
# 4       Rate    % CHANGE   USD     2023-10-31
# 5       Rate     % RATIO   NaN     2023-10-31
#
#                                       long_comp_name
# 0  Net % of Domestic Respondents Tightening Stand...
# 1  Net % of Domestic Respondents Tightening Stand...
# 2  Net % of Dom Respond Inc Spreads of Loan Rates...
# 3  Net % of Domestic Respondents Increasing Sprea...
# 4  Net % of Dom Respond Reporting Stronger Demand...
# 5  Net % of Domestic Respondents Reporting Strong...

# %%
BDH_List(T,13)
# Out:
#                                23/10 23/07 23/04 23/01
# Sup/Dem C&I LoanTight L/M       33.9  50.8  46.0  44.8
# Net % C&I Loans Tight Stands S  30.4  49.2  46.7  43.8
# Sup/Dem C&I LoanSpreads         50.0  68.3  62.3  44.8
# Net % COF Spread Loan Rates Sm  44.6  66.1  58.3  32.8
# Sup/Dem C&I LoanDemand         -30.5 -51.6 -55.6 -31.3
# Net % Strong Demd C&I  Loans S -49.1 -47.5 -53.3 -42.2

# %%
#NFIB
T = ["SBOITOTL","SBOIHIRE","SBOIBUSC","SBOIUNCR"] 
df_BDP = BDP(T)
df_BDP
# Out:
#             index                            name      security_name  \
# 0  SBOITOTL Index  NFIB Small Business Optimism I            Overall
# 1  SBOIHIRE Index  NFIB Small Business Hiring Pla             Hiring
# 2  SBOIBUSC Index  NFIB Small Business Outlook fo           Business
# 3  SBOIUNCR Index  NFIB Small Business Uncertaint  Uncertainty Index
#
#                        name_kanji px_last indx_freq indx_units  \
# 0                        中小企業楽観指数    91.9   Monthly      Value
# 1                        中小企業雇用計画    16.0   Monthly      Value
# 2                         中小企業景況感   -36.0   Monthly      Value
# 3  NFIB Small Business Uncertaint    71.0   Monthly      Value
#
#        quote_units last_update_dt  \
# 0  SEASONALLY ADJ.     2023-12-31
# 1              NaN     2023-12-31
# 2  SEASONALLY ADJ.     2023-12-31
# 3       Uncertaint     2023-12-31
#
#                                       long_comp_name crncy
# 0                 NFIB Small Business Optimism Index   NaN
# 1             NFIB Small Business Hiring Plans Index   USD
# 2  NFIB Small Business Outlook for General Busine...   USD
# 3              NFIB Small Business Uncertainty Index   USD

# %%
#SLOOS
T = ["SBOIARAT","SBOILOAN","SBOIRATE","SBOIRRRB","SBOIHIRE"] 
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=120)
d_from = "20070101"
df = BDH(T,d_from,d_to)
print(term())
Plot("NFIB Small Business Ave Interest rate on Short-term(中小企業調達金利)","SBOIARAT","")
Plot("NFIB Small Business Hiring Plan","SBOIHIRE","")
df_BDP = BDP(T)
df_BDP
# Out:
# 2007-01～2023-12
#             index                            name  \
# 0  SBOIARAT Index  NFIB Small Business Actual Ave
# 1  SBOILOAN Index  NFIB Small Business Credit Con
# 2  SBOIRATE Index   NFIB Small Business Financial
# 3  SBOIRRRB Index  NFIB Small Business Relative I
# 4  SBOIHIRE Index  NFIB Small Business Hiring Pla
#
#                   security_name                      name_kanji px_last  \
# 0  Actual Average Interest Rate  NFIB Small Business Actual Ave     9.8
# 1    SMALL BUSINESS  Avail Loan  NFIB Small Business Credit Con    -8.0
# 2    Financial & Interest Rates   NFIB Small Business Financial     5.0
# 3   Relative Interest Rate Paid  NFIB Small Business Relative I    20.0
# 4                        Hiring                        中小企業雇用計画    16.0
#
#   indx_freq indx_units last_update_dt  \
# 0   Monthly    Percent     2023-12-31
# 1   Monthly      Value     2023-12-31
# 2   Monthly       Rate     2023-12-31
# 3   Monthly      Value     2023-12-31
# 4   Monthly      Value     2023-12-31
#
#                                       long_comp_name crncy       quote_units
# 0  NFIB Small Business Actual Average Interest Ra...   NaN               NaN
# 1  NFIB Small Business Credit Conditions Availabi...   USD               NaN
# 2  NFIB Small Business Financial & Interest Rates...   NaN  Percentage Ratio
# 3  NFIB Small Business Relative Interest Rate Pai...   NaN               NaN
# 4             NFIB Small Business Hiring Plans Index   USD               NaN

# %%
T = ["CNSTTOTA","CNSTTYOY","CNSTTMOM","CNSTMANU"] 
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=120)
d_from = "20070101"
df = BDH(T,d_from,d_to)
print(term())
Plot("Construction Spending/Total","CNSTTOTA","")
Plot("Construction Spending/製造業","CNSTMANU","")
Plot("YoY","CNSTTYOY","",0)
Plot("MoM","CNSTTMOM","",0)
Plot("Census Bureau US Construction Spending Manufacturing (米国建設支出/製造業の推移)","CNSTMANU","")
df_BDP = BDP(T)
df_BDP
# Out:
# 2007-01～2023-11
#             index                           name     security_name  \
# 0  CNSTTOTA Index  Census Bureau US Construction             Total
# 1  CNSTTYOY Index  Census Bureau US Construction   Yearly % Change
# 2  CNSTTMOM Index  Census Bureau US Construction  Monthly % Change
# 3  CNSTMANU Index  Census Bureau US Construction     Manufacturing
#
#           name_kanji    px_last indx_freq indx_units quote_units crncy  \
# 0  米 国勢調査局 建設支出-合計(季  2050058.0   Monthly      Value     Million   USD
# 1  米 国勢調査局 建設支出-合計(前       11.3   Monthly    Percent           %   NaN
# 2  米 国勢調査局 建設支出-合計(前        0.4   Monthly       Rate    % CHANGE   NaN
# 3  米 国勢調査局 建設支出-製造 (   209778.0   Monthly      Value     Million   USD
#
#   last_update_dt                                     long_comp_name
# 0     2023-11-30    Census Bureau US Construction Spending Total SA
# 1     2023-11-30  Census Bureau US Construction Spending Total S...
# 2     2023-11-30    Census Bureau US Construction Spending MoM SAAR
# 3     2023-11-30  Census Bureau US Construction Spending Manufac...

# %%
# T = ['WCIDCOMP','BDIY'] 
T = ['WCIDCOMP'] 
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=120)
d_from = "20070101"
df = BDH(T,d_from,d_to)
print(term())
Plot("コンテナ運賃(Weekly)","WCIDCOMP","")
# Out:
# 2011-06～2024-01

# %% [markdown]
# ## China
# http://www.pbc.gov.cn/goutongjiaoliu/113456/113469/4975649/2023062915254732962.pdf <br>
# https://note.com/happy_talent/n/n65c931276659

# %%
# PMI    
T  = ["CPMINDX","CPMINMAN","CPMICOMP"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=350)
d_from = date(2005, 1, 1)
df = BDH(T,d_from,d_to)
print(term())
Plot("China Manufacturing PMI SA","CPMINDX","",50,"",30,65)
Plot("China Non-Manufacturing PMI SA","CPMINMAN","",50,"",30,65)
df_BDP = BDP(T)
df_BDP
# Out:
# 2005-01～2023-12
#             index                            name  \
# 0   CPMINDX Index      China Manufacturing PMI SA
# 1  CPMINMAN Index  China Non-Manufacturing PMI SA
# 2  CPMICOMP Index   China Composite PMI Output SA
#
#                    security_name             name_kanji px_last indx_freq  \
# 0               Manufacturing SA       中国 製造業購買担当者指数 季調    49.0   Monthly
# 1           Non-Manufacturing SA        中国 非製造業PMI(季調済)    50.4   Monthly
# 2  China Composite PMI Output SA  中国ｺﾝﾎﾟｼﾞｯﾄPMI生産高(季調済)    50.3   Monthly
#
#   indx_units quote_units last_update_dt                  long_comp_name
# 0    Percent      Points     2023-12-31      China Manufacturing PMI SA
# 1      Value      Points     2023-12-31  China Non-Manufacturing PMI SA
# 2      Value      Points     2023-12-31   China Composite PMI Output SA

# %%
BDH_List(T,13)
# Out:
#                               23/12 23/11 23/10 23/09 23/08 23/07 23/06 23/05  \
# Manufacturing SA               49.0  49.4  49.5  50.2  49.7  49.3  49.0  48.8
# Non-Manufacturing SA           50.4  50.2  50.6  51.7  51.0  51.5  53.2  54.5
# China Composite PMI Output SA  50.3  50.4  50.7  52.0  51.3  51.1  52.3  52.9
#
#                               23/04 23/03 23/02 23/01 22/12
# Manufacturing SA               49.2  51.9  52.6  50.1  47.0
# Non-Manufacturing SA           56.4  58.2  56.3  54.4  41.6
# China Composite PMI Output SA  54.4  57.0  56.4  52.9  42.6

# %%
# PMI Manufacturing
T  = ["CPMINDX","CPMIPROD","CPMINORD","CPMIIRAM","CPMIEMPL","CPMISUPL","CPMINEXO","CPMIIMPS",
      "CPMIPVOL","CPMIPRXP","CPMIPPI","CPMIIFGS","CPMINDOD","CPMIBEXP","CPMILCO","CPMIMCO","CPMISCO"]
d_to = workdays.workday(date.today(), days=0)
d_from = date(2005, 1, 1)
df = BDH(T,d_from,d_to)

df["diff"] = df["CPMINORD"] - df["CPMIIFGS"]
Plot("New Orders","CPMINORD","New Orders",50)
Plot("Inventories of Finished Goods","CPMIIFGS","Inventories of Finished Goods",50)
Plot("New orders - Inventories of Finished Goods","diff","diff",0)
Plot("PMI Manufacturing","CPMINDX","",50)

df_BDP = BDP(T)
df_BDP
# Out:
#              index                            name  \
# 0    CPMINDX Index      China Manufacturing PMI SA
# 1   CPMIPROD Index             China Output PMI SA
# 2   CPMINORD Index         China New Orders PMI SA
# 3   CPMIIRAM Index  China Inventories of Raw Mater
# 4   CPMIEMPL Index         China Employment PMI SA
# 5   CPMISUPL Index  China Suppliers' Delivery Time
# 6   CPMINEXO Index  China New Export Orders PMI SA
# 7   CPMIIMPS Index            China Imports PMI SA
# 8   CPMIPVOL Index  China Purchasing of Inputs PMI
# 9   CPMIPRXP Index       China Input Prices PMI SA
# 10   CPMIPPI Index     China Producer Price PMI SA
# 11  CPMIIFGS Index  China Stocks of Finished Goods
# 12  CPMINDOD Index  China Backlogs of Orders PMI S
# 13  CPMIBEXP Index   China Production and Business
# 14   CPMILCO Index         China Large Corp PMI SA
# 15   CPMIMCO Index        China Medium Corp PMI SA
# 16   CPMISCO Index         China Small Corp PMI SA
#
#                     security_name                     name_kanji px_last  \
# 0                Manufacturing SA               中国 製造業購買担当者指数 季調    49.0
# 1                       Output SA               中国 製造業購買担当者指数 生産    50.2
# 2                   New Orders SA               中国 製造業購買担当者指数 新規    48.7
# 3           China Inventories PMI               中国 製造業購買担当者指数 原材    47.7
# 4                   Employment SA               中国 製造業購買担当者指数 雇用    47.9
# 5     Supplier's Delivery Time SA             中国 製造業購買担当者指数 ｻﾌﾟﾗ    50.3
# 6            New Export Orders SA               中国 製造業購買担当者指数 新規    45.8
# 7                      Imports SA               中国 製造業購買担当者指数 輸入    46.4
# 8         Purchasing of Inputs SA               中国 製造業購買担当者指数 購買    49.0
# 9       China Input Prices PMI SA               中国 製造業購買担当者指数 購買    51.5
# 10              Producer Price SA    China Producer Price PMI SA    47.7
# 11    Stocks of Finished Goods SA               中国 製造業購買担当者指数 完成    47.8
# 12          Backlogs of Orders SA               中国 製造業購買担当者指数 受注    44.5
# 13  Production & Business Act Exp  China Production and Business    55.9
# 14           CN Large Corp PMI SA        China Large Corp PMI SA    50.0
# 15          CN Medium Corp PMI SA       China Medium Corp PMI SA    48.7
# 16           CN Small Corp PMI SA        China Small Corp PMI SA    47.3
#
#    indx_freq indx_units quote_units last_update_dt  \
# 0    Monthly    Percent      Points     2023-12-31
# 1    Monthly      Value      Points     2023-12-31
# 2    Monthly      Value      Points     2023-12-31
# 3    Monthly      Value      Points     2023-12-31
# 4    Monthly      Value      Points     2023-12-31
# 5    Monthly      Value      Points     2023-12-31
# 6    Monthly      Value      Points     2023-12-31
# 7    Monthly      Value      Points     2023-12-31
# 8    Monthly      Value      Points     2023-12-31
# 9    Monthly      Value      Points     2023-12-31
# 10   Monthly      Value      Points     2023-12-31
# 11   Monthly      Value      Points     2023-12-31
# 12   Monthly      Value      Points     2023-12-31
# 13   Monthly      Value      Points     2023-12-31
# 14   Monthly      Value      Points     2023-12-31
# 15   Monthly      Value      Points     2023-12-31
# 16   Monthly      Value      Points     2023-12-31
#
#                                        long_comp_name
# 0                          China Manufacturing PMI SA
# 1                                 China Output PMI SA
# 2                             China New Orders PMI SA
# 3           China Inventories of Raw Materials PMI SA
# 4                             China Employment PMI SA
# 5               China Suppliers' Delivery Time PMI SA
# 6                      China New Export Orders PMI SA
# 7                                China Imports PMI SA
# 8                   China Purchasing of Inputs PMI SA
# 9                           China Input Prices PMI SA
# 10                        China Producer Price PMI SA
# 11              China Stocks of Finished Goods PMI SA
# 12                    China Backlogs of Orders PMI SA
# 13  China Production and Business Activities Expec...
# 14                            China Large Corp PMI SA
# 15                           China Medium Corp PMI SA
# 16                            China Small Corp PMI SA

# %%
#PMI non-Manufacturing
T  = ["CPMINMAN","CPMINMNO","CPMINNOA","CPMINMSP","CPMINEMP",
      "CPMINMBP","CPMINMII","CPMINBLO","CPMINVNR","CPMINSPL"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=350)
d_from = date(2005, 1, 1)
df = BDH(T,d_from,d_to)
Plot("Industrial Total Inventory","CPMINMAN","Industrial Total Inventory",50)
df_BDP = BDP(T)
df_BDP
# Out:
#             index                            name  \
# 0  CPMINMAN Index  China Non-Manufacturing PMI SA
# 1  CPMINMNO Index   China Non-Manufacturing PMI -
# 2  CPMINNOA Index   China Non-Manufacturing PMI -
# 3  CPMINMSP Index   China Non-Manufacturing PMI -
# 4  CPMINEMP Index   China Non-Manufacturing PMI -
# 5  CPMINMBP Index   China Non-Manufacturing PMI -
# 6  CPMINMII Index   China Non-Manufacturing PMI -
# 7  CPMINBLO Index   China Non-Manufacturing PMI -
# 8  CPMINVNR Index   China Non-Manufacturing PMI -
# 9  CPMINSPL Index   China Non-Manufacturing PMI -
#
#                     security_name                     name_kanji px_last  \
# 0            Non-Manufacturing SA                中国 非製造業PMI(季調済)    50.4
# 1               N-Manu New Orders  China Non-Manufacturing PMI -    47.5
# 2     N-Manu New Export Orders SA  China Non-Manufacturing PMI -    50.9
# 3        N-Manu Subsciption Price  China Non-Manufacturing PMI -    49.3
# 4               N-Manu Employment  China Non-Manufacturing PMI -    47.1
# 5  N-Manu Business Activities Exp  China Non-Manufacturing PMI -    60.3
# 6       N-Manu Intermediate Input  China Non-Manufacturing PMI -    49.6
# 7    N-Manu Backlogs of Orders SA  China Non-Manufacturing PMI -    43.9
# 8           N-Manu Inventories SA  China Non-Manufacturing PMI -    46.0
# 9  N-Manu Supplier's DeliveryTime  China Non-Manufacturing PMI -    51.0
#
#   indx_freq indx_units quote_units last_update_dt  \
# 0   Monthly      Value      Points     2023-12-31
# 1   Monthly      Value      Points     2023-12-31
# 2   Monthly      Value      Points     2023-12-31
# 3   Monthly      Value      Points     2023-12-31
# 4   Monthly      Value      Points     2023-12-31
# 5   Monthly      Value      Points     2023-12-31
# 6   Monthly      Value      Points     2023-12-31
# 7   Monthly      Value      Points     2023-12-31
# 8   Monthly      Value      Points     2023-12-31
# 9   Monthly      Value      Points     2023-12-31
#
#                                       long_comp_name
# 0                     China Non-Manufacturing PMI SA
# 1  China Non-Manufacturing PMI - New Orders Index SA
# 2  China Non-Manufacturing PMI - New Export Order...
# 3  China Non-Manufacturing PMI - Subscription Pri...
# 4  China Non-Manufacturing PMI - Employment Index SA
# 5  China Non-Manufacturing PMI - Business Activit...
# 6  China Non-Manufacturing PMI - Intermediate Inp...
# 7  China Non-Manufacturing PMI - Backlogs of Orde...
# 8       China Non-Manufacturing PMI - Inventories SA
# 9  China Non-Manufacturing PMI - Suppliers' Deliv...

# %%
df
# Out:
#           Date  CPMINMAN  CPMINMNO  CPMINNOA  CPMINMSP  CPMINEMP  CPMINMBP  \
# 0   2007-01-31      60.4      57.3       NaN      49.9       NaN      75.4
# 1   2007-02-28      60.6      57.9       NaN      50.4       NaN      73.2
# 2   2007-03-31      58.2      56.9       NaN      49.6       NaN      72.2
# 3   2007-04-30      60.4      57.2       NaN      50.4       NaN      72.6
# 4   2007-05-31      62.2      57.5       NaN      51.5       NaN      72.6
# ..         ...       ...       ...       ...       ...       ...       ...
# 199 2023-08-31      51.0      47.5      47.9      50.0      46.8      58.2
# 200 2023-09-30      51.7      47.8      49.4      50.3      46.8      58.7
# 201 2023-10-31      50.6      46.7      49.1      48.6      46.5      58.1
# 202 2023-11-30      50.2      47.2      46.8      48.3      46.9      59.8
# 203 2023-12-31      50.4      47.5      50.9      49.3      47.1      60.3
#
#      CPMINMII  CPMINBLO  CPMINVNR  CPMINSPL
# 0        59.3       NaN       NaN       NaN
# 1        58.8       NaN       NaN       NaN
# 2        56.9       NaN       NaN       NaN
# 3        57.9       NaN       NaN       NaN
# 4        60.8       NaN       NaN       NaN
# ..        ...       ...       ...       ...
# 199      51.7      43.7      46.2      52.0
# 200      52.5      43.3      46.9      51.3
# 201      49.7      43.1      46.2      52.0
# 202      49.8      43.0      46.7      51.8
# 203      49.6      43.9      46.0      51.0
#
# [204 rows x 11 columns]

# %%
# ISM vs PM2.5
T  = ["CPMINDX"]
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=42)
df = BDH(T,d_from,d_to)
Plot("PMI Manufacturing","CPMINDX","",50)

T  = ["CAQIBEJI"]
df = BDH(T,d_from,d_to)
df["ave5"] = df["CAQIBEJI"].rolling(window=5).mean()
df["ave10"] = df["CAQIBEJI"].rolling(window=10).mean()
df["ave20"] = df["CAQIBEJI"].rolling(window=20).mean()
df["ave30"] = df["CAQIBEJI"].rolling(window=30).mean()
# Plot("China Air Quality Index Beijin","ave5","ave_5")
# Plot("China Air Quality Index Beijin","ave10","ave_10")
Plot("China Air Quality Index Beijin","ave20","ave_20")
Plot("China Air Quality Index Beijin","ave30","ave_30")
df_BDP = BDP(T)
df_BDP
# Out:
#             index                            name   security_name  \
# 0  CAQIBEJI Index  China Air Quality Index Beijin  CN AQI Beijing
#
#                        name_kanji px_last indx_freq last_update_dt  \
# 0  China Air Quality Index Beijin    63.0  Intraday     2024-01-25
#
#                     long_comp_name
# 0  China Air Quality Index Beijing

# %%
#Export
T  = ["CNFREXP$","CNTSECN","CHEXUS","CHEXCA","CHEXHK","CHEXJPN",
    "CHEXKR","CHEXTW","CHEXIN","CHEXASEA","CHEXEU","CHEXGB","CHEXRU"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=350)
d_from = date(2005, 1, 1)
df = BDH(T,d_from,d_to)
Plot("US","CNFREXP$","US")
Plot("US","CHEXUS","US")
df_BDP = BDP(T)
df_BDP
# Out:
#              index                            name  \
# 0   CNFREXP$ Index              China Export Trade
# 1    CNTSECN Index          China Export Trade CNY
# 2     CHEXUS Index             China Exports to US
# 3     CHEXCA Index         China Exports to Canada
# 4     CHEXHK Index      China Exports to Hong Kong
# 5    CHEXJPN Index          China Exports to Japan
# 6     CHEXKR Index          China Exports to Korea
# 7     CHEXTW Index         China Exports to Taiwan
# 8     CHEXIN Index          China Exports to India
# 9   CHEXASEA Index  China Exports to Association o
# 10    CHEXEU Index  China Exports to European Unio
# 11    CHEXGB Index             China Exports to UK
# 12    CHEXRU Index         China Exports to Russia
#
#                     security_name                      name_kanji    px_last  \
# 0                          Export                         中国 輸出貿易    303.618
# 1          China Export Trade CNY          China Export Trade CNY    2175.35
# 2                              US                        中国 輸出 米国   42243.66
# 3                          Canada                      中国 輸出 ｶﾅﾀﾞ   4079.511
# 4                       Hong Kong                        中国 輸出 香港  29240.582
# 5                           Japan                        中国 輸出 日本  13081.284
# 6                     South Korea                        中国 輸出 韓国   13084.05
# 7                          Taiwan                        中国 輸出 台湾   5984.871
# 8                           India                      中国 輸出 ｲﾝﾄﾞ  10462.862
# 9   Asstn of S East Asian Nations  China Exports to Association o   50196.72
# 10                 European Union  China Exports to European Unio   42756.82
# 11                             UK                        中国 輸出 英国   7130.383
# 12                         Russia                       中国 輸出 ﾛｼｱ  10709.681
#
#    indx_freq indx_units quote_units crncy last_update_dt  \
# 0    Monthly      Value     Billion   USD     2023-12-31
# 1    Monthly      Value     Billion   CNY     2023-12-31
# 2    Monthly      Value     Million   USD     2023-12-31
# 3    Monthly      Value     Million   USD     2023-12-31
# 4    Monthly      Value     Million   USD     2023-12-31
# 5    Monthly      Value     Million   USD     2023-12-31
# 6    Monthly      Value     Million   USD     2023-12-31
# 7    Monthly      Value     Million   USD     2023-12-31
# 8    Monthly      Value     Million   USD     2023-12-31
# 9    Monthly      Value    Millions   USD     2023-12-31
# 10   Monthly      Value    Millions   USD     2023-12-31
# 11   Monthly      Value     Million   USD     2023-12-31
# 12   Monthly      Value     Million   USD     2023-12-31
#
#                                        long_comp_name
# 0                                  China Export Trade
# 1                              China Export Trade CNY
# 2                                 China Exports to US
# 3                             China Exports to Canada
# 4                          China Exports to Hong Kong
# 5                              China Exports to Japan
# 6                              China Exports to Korea
# 7                             China Exports to Taiwan
# 8                              China Exports to India
# 9   China Exports to Association of Southeast Asia...
# 10                    China Exports to European Union
# 11                                China Exports to UK
# 12                            China Exports to Russia

# %%
#Import
T  = ["CNFRIMP$","CHTIUS","CHTIEU","CHTIJPN","CNFRIMPY","CHTIUSY"]


d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=350)
d_from = date(2005, 1, 1)
df = BDH(T,d_from,d_to)
Plot("China Import Trade","CNFRIMP$","USD billion")
Plot("China Import Trade from US","CHTIUS","USD million")
Plot("China Import Trade from EU","CHTIEU","USD million")
Plot("China Import Trade from Japan","CHTIJPN","USD million")

Plot("China Import Trade","CNFRIMPY","YoY",0)
Plot("China Import Trade from US","CHTIUSY","YoY",0)
df_BDP = BDP(T)
df_BDP
# Out:
#             index                            name        security_name  \
# 0  CNFRIMP$ Index              China Import Trade               Import
# 1    CHTIUS Index           China Imports from US                   US
# 2    CHTIEU Index  China Imports from European Un       European Union
# 3   CHTIJPN Index        China Imports from Japan                Japan
# 4  CNFRIMPY Index      China Import Trade USD YoY           Import YoY
# 5   CHTIUSY Index  China Imports from US - USD Yo  CH IM from US - YoY
#
#                        name_kanji    px_last indx_freq indx_units quote_units  \
# 0                         中国 輸入貿易    228.278   Monthly      Value     Billion
# 1                        中国 輸入 米国  14937.852   Monthly      Value     Million
# 2  China Imports from European Un   24048.05   Monthly      Value    Millions
# 3                        中国 輸入 日本  14973.387   Monthly      Value     Million
# 4                   中国 輸入貿易USD前年比        0.2   Monthly       Rate    % CHANGE
# 5  China Imports from US - USD Yo       -6.1   Monthly       Rate           %
#
#   crncy last_update_dt                     long_comp_name
# 0   USD     2023-12-31                 China Import Trade
# 1   USD     2023-12-31              China Imports from US
# 2   USD     2023-12-31  China Imports from European Union
# 3   USD     2023-12-31           China Imports from Japan
# 4   NaN     2023-12-31         China Import Trade USD YoY
# 5   NaN     2023-12-31    China Imports from US - USD YoY

# %%
#TradeBalance
T = ["CNFRIMPY","CNFRBAL$","CNFREXPY","CNTSECNY",
     "CNTSICNY","CNTSTCN","CNDIACRY","SWFTCNY"]

d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=350)
d_from = date(2005, 1, 1)
df = BDH(T,d_from,d_to)
Plot("US","CNFRIMPY","US",0)
df_BDP = BDP(T)
df_BDP
# Out:
#             index                            name  \
# 0  CNFRIMPY Index      China Import Trade USD YoY
# 1  CNFRBAL$ Index   China Imports & Exports Trade
# 2  CNFREXPY Index      China Export Trade USD YoY
# 3  CNTSECNY Index      China Export Trade CNY YoY
# 4  CNTSICNY Index      China Import Trade CNY YoY
# 5   CNTSTCN Index         China Trade Balance CNY
# 6  CNDIACRY Index  China FDI Foreign Capital Actu
# 7   SWFTCNY Index  Share of Payments via SWIFT in
#
#                  security_name                      name_kanji px_last  \
# 0                   Import YoY                   中国 輸入貿易USD前年比     0.2
# 1                Trade Balance                         中国 貿易収支   75.34
# 2                   Export YoY                     中国 輸出貿易 前年比     2.3
# 3   China Export Trade CNY YoY                 中国 輸出貿易CNY(前年比)     3.8
# 4  China Trade Main Im CNY YoY                 中国 輸入貿易CNY(前年比)     1.6
# 5      China Trade Main TB CNY                       中国貿易収支CNY   540.9
# 6            Total CNY YTD YoY  China FDI Foreign Capital Actu    -8.0
# 7     Share of Payments in CNY               SWIF経由CNY決済額比率(%)    4.14
#
#   indx_freq indx_units quote_units last_update_dt  \
# 0   Monthly       Rate    % CHANGE     2023-12-31
# 1   Monthly      Value     Billion     2023-12-31
# 2   Monthly       Rate    % CHANGE     2023-12-31
# 3   Monthly       Rate           %     2023-12-31
# 4   Monthly       Rate           %     2023-12-31
# 5   Monthly      Value     Billion     2023-12-31
# 6   Monthly    Percent           %     2023-12-31
# 7   Monthly    Percent           %     2023-12-31
#
#                                       long_comp_name crncy
# 0                         China Import Trade USD YoY   NaN
# 1        China Imports & Exports Trade Balance Value   USD
# 2                         China Export Trade USD YoY   NaN
# 3                         China Export Trade CNY YoY   NaN
# 4                         China Import Trade CNY YoY   NaN
# 5                            China Trade Balance CNY   CNY
# 6  China FDI Foreign Capital Actually Utilized Cu...   NaN
# 7             Share of Payments via SWIFT in CNY (%)   NaN

# %%
# Semiconductor 
T = ["CNIVDIOS","CNEVDIOS"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=350)
d_from = date(2005, 1, 1)
df = BDH(T,d_from,d_to)
Plot("China Import Volume:Diode&Semicon(半導体などの輸入数量)","CNIVDIOS","volume billion")
Plot("China Export Volume:Diode&Semicon(半導体などの輸出数量)","CNEVDIOS","volume billion")
df_BDP = BDP(T)
df_BDP
# Out:
#             index                           name  security_name  \
# 0  CNIVDIOS Index  China Import Commodity Volume  Diode&Semicon
# 1  CNEVDIOS Index  China Export Commodity Volume  Diode&Semicon
#
#           name_kanji px_last indx_freq indx_units quote_units last_update_dt  \
# 0  中国 商品輸入 出来高- 発光素子    41.3   Monthly     Volume     Billion     2023-12-31
# 1  中国 商品輸出 出来高- 発光素子    54.2   Monthly     Volume     Billion     2023-12-31
#
#                                       long_comp_name
# 0  China Import Commodity Volume - Diode & Semico...
# 1  China Export Commodity Volume - Diode & Semico...

# %%
# 長江商学院: 設備投資意欲(中小企業ターゲット) 
T= ["CKGSBCI","CKGSBCS","CKGSBCP","CKGSBCF","CKGSBIN","CKGSBLC","CKGSBAC",
    "CKGSBCPI","CKGSBPPI","CKGSBIV","CKGSBREC","CKGSBIC"]
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=150)
df = BDH(T,d_from,d_to)
Plot("China CKGSB Business Condition Investment (中小企業の投資意欲)","CKGSBIV","",50)
Plot("China CKGSB Business Condition Overall (中小企業の景況感)","CKGSBCI","",50)
df_BDP = BDP(T)
df_BDP
# Out:
#              index                            name  \
# 0    CKGSBCI Index  China CKGSB Business Condition
# 1    CKGSBCS Index  China CKGSB Business Condition
# 2    CKGSBCP Index  China CKGSB Business Condition
# 3    CKGSBCF Index  China CKGSB Business Condition
# 4    CKGSBIN Index  China CKGSB Business Condition
# 5    CKGSBLC Index  China CKGSB Business Condition
# 6    CKGSBAC Index  China CKGSB Business Condition
# 7   CKGSBCPI Index  China CKGSB Business Condition
# 8   CKGSBPPI Index  China CKGSB Business Condition
# 9    CKGSBIV Index  China CKGSB Business Condition
# 10  CKGSBREC Index  China CKGSB Business Condition
# 11   CKGSBIC Index  China CKGSB Business Condition
#
#                      security_name                      name_kanji px_last  \
# 0         Business Condition Index  China CKGSB Business Condition    51.1
# 1            Corporate Sales Index  China CKGSB Business Condition    60.9
# 2           Corporate Profit Index  China CKGSB Business Condition    52.7
# 3        Corporate Financing Index  China CKGSB Business Condition    44.3
# 4                  Inventory Index  China CKGSB Business Condition    47.9
# 5                Labor Costs Index  China CKGSB Business Condition    64.0
# 6              Overall Costs Index  China CKGSB Business Condition    66.4
# 7            Consumer Prices Index  China CKGSB Business Condition    49.4
# 8            Producer Prices Index  China CKGSB Business Condition    40.2
# 9                 Investment Index  China CKGSB Business Condition    55.5
# 10               Recruitment Index  China CKGSB Business Condition    55.7
# 11  Industry Competitiveness Index  China CKGSB Business Condition    69.5
#
#    indx_freq indx_units last_update_dt  \
# 0    Monthly      Value     2024-01-31
# 1    Monthly      Value     2024-01-31
# 2    Monthly      Value     2024-01-31
# 3    Monthly      Value     2024-01-31
# 4    Monthly      Value     2024-01-31
# 5    Monthly      Value     2024-01-31
# 6    Monthly      Value     2024-01-31
# 7    Monthly      Value     2024-01-31
# 8    Monthly      Value     2024-01-31
# 9    Monthly      Value     2024-01-31
# 10   Monthly      Value     2024-01-31
# 11   Monthly      Value     2024-01-31
#
#                                        long_comp_name
# 0   China CKGSB Business Conditions - Overall Busi...
# 1   China CKGSB Business Conditions - Corporate Sa...
# 2   China CKGSB Business Conditions - Corporate Pr...
# 3   China CKGSB Business Conditions - Corporate Fi...
# 4   China CKGSB Business Conditions - Inventory Index
# 5   China CKGSB Business Conditions - Labor Costs ...
# 6   China CKGSB Business Conditions - Overall Cost...
# 7   China CKGSB Business Conditions - Consumer Pri...
# 8   China CKGSB Business Conditions - Producer Pri...
# 9   China CKGSB Business Conditions - Investment I...
# 10  China CKGSB Business Conditions - Recruitment ...
# 11  China CKGSB Business Conditions - Industry Com...

# %%
# CKGSB Business Sentiment
T = ["CKGSBUSI","CKGSCURR","CKGSEXPE","CKGSINVE","CKGSPROD","CKGSEMPL",
    "CKGSPRIC","CKGSELEC","CKGSINVN","CKGSOVER","CKGSOVES","CKGSUNIT",
    "CKGSLABO","CKGSRAWM","CKGSLEND" ]

d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=150)
df = BDH(T,d_from,d_to)
Plot("Industrial Total Inventory","CKGSLEND","Industrial Total Inventory")

df_BDP = BDP(T)
df_BDP
# Out:
#              index                            name  \
# 0   CKGSBUSI Index  China CKGSB Business Sentiment
# 1   CKGSCURR Index  China CKGSB Business Sentiment
# 2   CKGSEXPE Index  China CKGSB Business Sentiment
# 3   CKGSINVE Index  China CKGSB Business Sentiment
# 4   CKGSPROD Index  China CKGSB Business Sentiment
# 5   CKGSEMPL Index  China CKGSB Business Sentiment
# 6   CKGSPRIC Index  China CKGSB Business Sentiment
# 7   CKGSELEC Index  China CKGSB Business Sentiment
# 8   CKGSINVN Index  China CKGSB Business Sentiment
# 9   CKGSOVER Index  China CKGSB Business Sentiment
# 10  CKGSOVES Index  China CKGSB Business Sentiment
# 11  CKGSUNIT Index  China CKGSB Business Sentiment
# 12  CKGSLABO Index  China CKGSB Business Sentiment
# 13  CKGSRAWM Index  China CKGSB Business Sentiment
# 14  CKGSLEND Index  China CKGSB Business Sentiment
#
#                      security_name                      name_kanji px_last  \
# 0         Business Sentiment Index  China CKGSB Business Sentiment    50.0
# 1     Current Operating Conditions  China CKGSB Business Sentiment    53.0
# 2    Expected Operating Conditions  China CKGSB Business Sentiment    52.0
# 3                Investment Timing  China CKGSB Business Sentiment    45.0
# 4                       Production  China CKGSB Business Sentiment    36.0
# 5                       Employment  China CKGSB Business Sentiment    49.0
# 6                            Price  China CKGSB Business Sentiment    56.0
# 7          Electricity Consumption  China CKGSB Business Sentiment    36.0
# 8                        Inventory  China CKGSB Business Sentiment    35.0
# 9   Over-Supply In Domestic Market  China CKGSB Business Sentiment    97.0
# 10   Over-Supply In Foreign Market  China CKGSB Business Sentiment   100.0
# 11                Unit Cost Change  China CKGSB Business Sentiment    61.0
# 12               Labor Cost Change  China CKGSB Business Sentiment    51.0
# 13        Raw Material Cost Change  China CKGSB Business Sentiment    62.0
# 14                Lending Attitude  China CKGSB Business Sentiment    66.0
#
#     indx_freq indx_units last_update_dt  \
# 0   Quarterly      Value     2022-12-31
# 1   Quarterly      Value     2022-12-31
# 2   Quarterly      Value     2022-12-31
# 3   Quarterly      Value     2022-12-31
# 4   Quarterly      Value     2022-12-31
# 5   Quarterly      Value     2022-12-31
# 6   Quarterly      Value     2022-12-31
# 7   Quarterly      Value     2022-12-31
# 8   Quarterly      Value     2022-12-31
# 9   Quarterly      Value     2022-12-31
# 10  Quarterly      Value     2022-12-31
# 11  Quarterly      Value     2022-12-31
# 12  Quarterly      Value     2022-12-31
# 13  Quarterly      Value     2022-12-31
# 14  Quarterly      Value     2022-12-31
#
#                                        long_comp_name
# 0            China CKGSB Business Sentiment - Overall
# 1   China CKGSB Business Sentiment - Current Opera...
# 2   China CKGSB Business Sentiment - Expected Oper...
# 3   China CKGSB Business Sentiment - Investment Ti...
# 4         China CKGSB Business Sentiment - Production
# 5         China CKGSB Business Sentiment - Employment
# 6              China CKGSB Business Sentiment - Price
# 7   China CKGSB Business Sentiment - Electricity C...
# 8          China CKGSB Business Sentiment - Inventory
# 9   China CKGSB Business Sentiment - Over-Supply I...
# 10  China CKGSB Business Sentiment - Over-Supply I...
# 11  China CKGSB Business Sentiment - Unit Cost Change
# 12  China CKGSB Business Sentiment - Labor Cost Ch...
# 13  China CKGSB Business Sentiment - Raw Material ...
# 14  China CKGSB Business Sentiment - Lending Attit...

# %%
#BMH: Bankers Macroeconomic Heat
T = ["CNBSBMHI","CNBSMONE","CNBSLOAN","CNBSLOM","CNBSINFT","CNBSLOLE",
    "CNBSLOME","CNBSLOSE","CNBSLOAP","CNBSCLMT","CNBSPROF"]

d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=150)
df = BDH(T,d_from,d_to)
Plot("Industrial Total Inventory","CNBSLOAN","Industrial Total Inventory")

df_BDP = BDP(T)
df_BDP
# Out:
#              index                            name  \
# 0   CNBSBMHI Index  People's Bank of China Bankers
# 1   CNBSMONE Index  People's Bank of China Bankers
# 2   CNBSLOAN Index  People's Bank of China Bankers
# 3    CNBSLOM Index  People's Bank of China Bankers
# 4   CNBSINFT Index  People's Bank of China Bankers
# 5   CNBSLOLE Index  People's Bank of China Bankers
# 6   CNBSLOME Index  People's Bank of China Bankers
# 7   CNBSLOSE Index  People's Bank of China Bankers
# 8   CNBSLOAP Index  People's Bank of China Bankers
# 9   CNBSCLMT Index  People's Bank of China Bankers
# 10  CNBSPROF Index  People's Bank of China Bankers
#
#                    security_name                      name_kanji px_last  \
# 0     Bankers Macroeconomic Heat  People's Bank of China Bankers    37.8
# 1             M.Policy Sentiment                中国人民銀行 銀行調査､金融政策    64.2
# 2                    Loan Demand                中国人民銀行 銀行調査 借入需要    62.2
# 3              Loan Demand Manuf  People's Bank of China Bankers    64.1
# 4   Loan Demand Index - Infrastr  People's Bank of China Bankers    61.0
# 5              Large Enterprises  People's Bank of China Bankers    55.1
# 6             Medium Enterprises  People's Bank of China Bankers    58.1
# 7                Loan Demand SME  People's Bank of China Bankers    64.5
# 8          Loan Approval Climate  People's Bank of China Bankers    55.6
# 9       Banking Industry Climate                中国人民銀行 銀行調査 銀行業務    69.6
# 10   Banks Profitability Climate  People's Bank of China Bankers    62.2
#
#     indx_freq indx_units last_update_dt  \
# 0   Quarterly      Value     2023-06-30
# 1   Quarterly      Value     2023-06-30
# 2   Quarterly      Value     2023-06-30
# 3   Quarterly      Value     2023-06-30
# 4   Quarterly      Value     2023-06-30
# 5   Quarterly      Value     2023-06-30
# 6   Quarterly      Value     2023-06-30
# 7   Quarterly      Value     2023-06-30
# 8   Quarterly      Value     2023-06-30
# 9   Quarterly      Value     2023-06-30
# 10  Quarterly      Value     2023-06-30
#
#                                        long_comp_name
# 0   People's Bank of China Bankers Survey Bankers ...
# 1   People's Bank of China Bankers Survey Monetary...
# 2   People's Bank of China Bankers Survey Overall ...
# 3   People's Bank of China Bankers Survey Loan Dem...
# 4   People's Bank of China Bankers Survey Loan Dem...
# 5   People's Bank of China Bankers Survey Loan Dem...
# 6   People's Bank of China Bankers Survey Loan Dem...
# 7   People's Bank of China Bankers Survey Loan Dem...
# 8   People's Bank of China Bankers Survey - Confid...
# 9   People's Bank of China Bankers Survey Banking ...
# 10  People's Bank of China Bankers Survey Banks Pr...

# %%
BDH_List(T,13)
# Out:
#                              23/06 23/03 22/12
# Bankers Macroeconomic Heat    37.8  40.2  17.4
# M.Policy Sentiment            64.2  67.7  68.0
# Loan Demand                   62.2  78.4  59.5
# Loan Demand Manuf             64.1  73.9  62.2
# Loan Demand Index - Infrastr  61.0  71.0  60.6
# Large Enterprises             55.1  64.9  54.6
# Medium Enterprises            58.1  68.2  56.4
# Loan Demand SME               64.5  76.5  62.5
# Loan Approval Climate         55.6  57.7  57.9
# Banking Industry Climate      69.6  71.9  65.8
# Banks Profitability Climate   62.2  66.0  61.3

# %%
T = ["CINIIE"]
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=150)
df = BDH(T,d_from,d_to)
Plot("Industrial Total Inventory","CINIIE","Industrial Total Inventory")

df_BDP = BDP(T)
df_BDP
# Out:
#           index                            name           security_name  \
# 0  CINIIE Index  China Industrial Total Invento  CH Ind Tt Inventory IE
#
#                        name_kanji   px_last indx_freq indx_units  \
# 0  China Industrial Total Invento  164328.2   Monthly      Value
#
#     quote_units crncy last_update_dt  \
# 0  100 Millions   CNY     2023-11-30
#
#                                       long_comp_name
# 0  China Industrial Total Inventory - Industrial ...

# %%
T = ["CNLNASF","CNLNNEW","CNMS0YOY","CNMS1YOY","CNMS2YOY"]
d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=150)
df = BDH(T,d_from,d_to)
Plot("Utilization Rate","CNLNNEW","Utilization Rate")

df_BDP = BDP(T)
df_BDP
# Out:
#             index                            name         security_name  \
# 0   CNLNASF Index  China All-system Financing Agg  Total Social Finance
# 1   CNLNNEW Index      China CNY Monthly New Loan              New Loan
# 2  CNMS0YOY Index   China Monthly Money Supply M0                M0 YOY
# 3  CNMS1YOY Index   China Monthly Money Supply M1                M1 YoY
# 4  CNMS2YOY Index   China Monthly Money Supply M2                M2 YoY
#
#            name_kanji  px_last indx_freq indx_units quote_units crncy  \
# 0      中国 全ｼｽﾃﾑ資金調達総額   1940.1   Monthly      Value     Billion   CNY
# 1     中国 月次新規ﾛｰﾝ(CNY)  1170.89   Monthly      Value     Billion   CNY
# 2  中国 ﾏﾈｰｻﾌﾟﾗｲ M0 前年比      8.3   Monthly       Rate    % CHANGE   NaN
# 3  中国 ﾏﾈｰｻﾌﾟﾗｲ M1 前年比      1.3   Monthly       Rate    % CHANGE   NaN
# 4         ﾏﾈｰｻ M2 前年比      9.7   Monthly       Rate    % CHANGE   NaN
#
#   last_update_dt                        long_comp_name
# 0     2023-12-31  China All-system Financing Aggregate
# 1     2023-12-31            China CNY Monthly New Loan
# 2     2023-12-31     China Monthly Money Supply M0 YoY
# 3     2023-12-31     China Monthly Money Supply M1 YoY
# 4     2023-12-31     China Monthly Money Supply M2 YoY

# %%
# Utilization Rate
T = ["CNURTOTL","CNURMINI","CNURMANU","CNURELEC","CNURMICO","CNURPTRO",
     "CNURFOOD","CNURTEXT","CNURCHEM","CNURMEDI","CNURCHEF","CNURNONM",
     "CNURMETL","CNURNONF","CNURGEMH","CNURSPMH","CNURAUTO","CNUREMEP","CNUREQIP"]

d_to = workdays.workday(date.today(), days=0)
d_from = d_to - relativedelta(months=150)
df = BDH(T,d_from,d_to)
Plot("Utilization Rate","CNURTOTL","Utilization Rate")

df_BDP = BDP(T)
df_BDP
# Out:
#              index                            name  \
# 0   CNURTOTL Index  China Utilization Rate of Indu
# 1   CNURMINI Index  China Utilization Rate of Indu
# 2   CNURMANU Index  China Utilization Rate of Indu
# 3   CNURELEC Index  China Utilization Rate of Indu
# 4   CNURMICO Index  China Utilization Rate of Indu
# 5   CNURPTRO Index  China Utilization Rate of Indu
# 6   CNURFOOD Index  China Utilization Rate of Indu
# 7   CNURTEXT Index  China Utilization Rate of Indu
# 8   CNURCHEM Index  China Utilization Rate of Indu
# 9   CNURMEDI Index  China Utilization Rate of Indu
# 10  CNURCHEF Index  China Utilization Rate of Indu
# 11  CNURNONM Index  China Utilization Rate of Indu
# 12  CNURMETL Index  China Utilization Rate of Indu
# 13  CNURNONF Index  China Utilization Rate of Indu
# 14  CNURGEMH Index  China Utilization Rate of Indu
# 15  CNURSPMH Index  China Utilization Rate of Indu
# 16  CNURAUTO Index  China Utilization Rate of Indu
# 17  CNUREMEP Index  China Utilization Rate of Indu
# 18  CNUREQIP Index  China Utilization Rate of Indu
#
#                      security_name                      name_kanji px_last  \
# 0        CN Indus Utilization Rate  China Utilization Rate of Indu    75.9
# 1     CN Indus UR Mining&Quarrying  China Utilization Rate of Indu    77.1
# 2        CN Indus UR Manufacturing  China Utilization Rate of Indu    76.0
# 3     CN Indus UR ElecHeatGasWater  China Utilization Rate of Indu    74.4
# 4   CN Indus UR Mining&WashingCoal  China Utilization Rate of Indu    75.6
# 5            CN Indus UR Petro&Gas  China Utilization Rate of Indu    92.1
# 6                 CN Indus UR Food  China Utilization Rate of Indu    71.3
# 7              CN Indus UR Textile  China Utilization Rate of Indu    76.2
# 8             CN Indus UR Chemical  China Utilization Rate of Indu    76.7
# 9            CN Indus UR Medicines  China Utilization Rate of Indu    75.4
# 10     CN Indus UR Chemical Fibers  China Utilization Rate of Indu    85.7
# 11    CN Indus UR Nonmetal Mineral  China Utilization Rate of Indu    64.7
# 12       CN Indus UR Ferrous Metal  China Utilization Rate of Indu    76.4
# 13  CN Indus UR Non-Ferrous Metals  China Utilization Rate of Indu    79.6
# 14    CN Indus UR GeneralMachinery  China Utilization Rate of Indu    79.2
# 15    CN Indus UR SpecialMachinery  China Utilization Rate of Indu    77.5
# 16                CN Indus UR Auto  China Utilization Rate of Indu    76.9
# 17      CN Indus UR Elec Machinery  China Utilization Rate of Indu    77.1
# 18  CN Indus UR Computer&Ele Equip  China Utilization Rate of Indu    77.6
#
#     indx_freq indx_units last_update_dt  \
# 0   Quarterly       Rate     2023-12-31
# 1   Quarterly       Rate     2023-12-31
# 2   Quarterly       Rate     2023-12-31
# 3   Quarterly       Rate     2023-12-31
# 4   Quarterly       Rate     2023-12-31
# 5   Quarterly       Rate     2023-12-31
# 6   Quarterly       Rate     2023-12-31
# 7   Quarterly       Rate     2023-12-31
# 8   Quarterly       Rate     2023-12-31
# 9   Quarterly       Rate     2023-12-31
# 10  Quarterly       Rate     2023-12-31
# 11  Quarterly       Rate     2023-12-31
# 12  Quarterly       Rate     2023-12-31
# 13  Quarterly       Rate     2023-12-31
# 14  Quarterly       Rate     2023-12-31
# 15  Quarterly       Rate     2023-12-31
# 16  Quarterly       Rate     2023-12-31
# 17  Quarterly       Rate     2023-12-31
# 18  Quarterly       Rate     2023-12-31
#
#                                        long_comp_name
# 0       China Utilization Rate of Industrial Capacity
# 1   China Utilization Rate of Industrial Capacity-...
# 2   China Utilization Rate of Industrial Capacity-...
# 3   China Utilization Rate of Industrial Capacity-...
# 4   China Utilization Rate of Industrial Capacity-...
# 5   China Utilization Rate of Industrial Capacity-...
# 6   China Utilization Rate of Industrial Capacity-...
# 7   China Utilization Rate of Industrial Capacity-...
# 8   China Utilization Rate of Industrial Capacity-...
# 9   China Utilization Rate of Industrial Capacity-...
# 10  China Utilization Rate of Industrial Capacity-...
# 11  China Utilization Rate of Industrial Capacity-...
# 12  China Utilization Rate of Industrial Capacity-...
# 13  China Utilization Rate of Industrial Capacity-...
# 14  China Utilization Rate of Industrial Capacity-...
# 15  China Utilization Rate of Industrial Capacity-...
# 16  China Utilization Rate of Industrial Capacity-...
# 17  China Utilization Rate of Industrial Capacity-...
# 18  China Utilization Rate of Industrial Capacity-...

# %%
BDH_List(T,13)
# Out:
#                                23/12 23/09 23/06 23/03 22/12
# CN Indus Utilization Rate       75.9  75.6  74.5  74.3  75.7
# CN Indus UR Mining&Quarrying    77.1  75.4  74.8  75.2  76.5
# CN Indus UR Manufacturing       76.0  75.8  74.8  74.5  75.8
# CN Indus UR ElecHeatGasWater    74.4  74.2  71.4  71.9  74.0
# CN Indus UR Mining&WashingCoal  75.6  73.8  74.5  73.8  75.4
# CN Indus UR Petro&Gas           92.1  91.2  90.9  91.2  91.3
# CN Indus UR Food                71.3  71.1  68.1  70.7  71.9
# CN Indus UR Textile             76.2  76.9  76.9  75.5  76.2
# CN Indus UR Chemical            76.7  74.6  74.3  75.5  76.0
# CN Indus UR Medicines           75.4  72.7  76.2  75.2  77.6
# CN Indus UR Chemical Fibers     85.7  85.1  84.1  82.1  79.2
# CN Indus UR Nonmetal Mineral    64.7  65.0  65.1  63.9  67.2
# CN Indus UR Ferrous Metal       76.4  79.1  79.0  78.1  73.5
# CN Indus UR Non-Ferrous Metals  79.6  80.2  80.3  77.8  79.4
# CN Indus UR GeneralMachinery    79.2  78.7  79.7  79.1  79.3
# CN Indus UR SpecialMachinery    77.5  77.5  78.1  77.0  77.5
# CN Indus UR Auto                76.9  75.6  73.3  72.0  73.2
# CN Indus UR Elec Machinery      77.1  77.8  77.1  75.8  79.0
# CN Indus UR Computer&Ele Equip  77.6  76.5  74.6  73.7  78.5

# %%
# https://www.komatsu.jp/ja/-/media/home/ir/library/demand-orders/ja/komtrax.pdf?rev=1b2084a931894a6db346b967d206b1da&hash=7FA0FBE59A28C5E68C47DE37F5B0B517
# 月次Komtraxデータ
T = ["CHMMEXCY","CHYXGLAS"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=150)
d_from = date(2016, 5, 1)
df = BDH(T,d_from,d_to)
Plot("Output Volume for Excavator YoY(掘削機)","CHMMEXCY","",0)
Plot("Output Volume for Plate Glass YoY(板ガラス)","CHYXGLAS","",0)
df_BDP = BDP(T)
df_BDP
# Out:
#             index                           name security_name  \
# 0  CHMMEXCY Index  China Industrial Output YoY -      Exca YoY
# 1  CHYXGLAS Index  China Industrial Output YoY -   Plate Glass
#
#                       name_kanji px_last indx_freq indx_units quote_units  \
# 0  China Industrial Output YoY -    -4.6   Monthly    Percent           %
# 1             中国 工業生産 前年比- 板ｶﾞﾗｽ     5.7   Monthly    Percent           %
#
#   last_update_dt                             long_comp_name
# 0     2023-12-31    China Industrial Output YoY - Excavator
# 1     2023-12-31  China Industrial Output YoY - Plate Glass

# %%
T = ["CHBDPNDT","CHPOP"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=150)
d_from = date(2010, 1, 1)
df = BDH(T,d_from,d_to)
Plot("Domestic CNY Households(billion, 預金総額)","CHBDPNDT","")
df_BDP = BDP(T)
df_BDP
# Out:
#             index                           name     security_name  \
# 0  CHBDPNDT Index  China Domestic CNY Households  RMB HseHold Depo
# 1     CHPOP Index         China Population Total             Total
#
#                       name_kanji    px_last indx_freq indx_units quote_units  \
# 0  China Domestic CNY Households  136598.37   Monthly      Value     Billion
# 1                         中国 総人口    1409.67    Yearly   Quantity    Millions
#
#   crncy last_update_dt                              long_comp_name
# 0   CNY     2023-12-31  China Domestic CNY Households Deposits Cum
# 1   NaN     2023-12-31                      China Population Total

# %%
T = ["CHPOP"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=150)
d_from = date(2010, 1, 1)
df = BDH(T,d_from,d_to)
Plot("China Population Total","CHPOP","")
df_BDP = BDP(T)
df_BDP
# Out:
#          index                    name security_name name_kanji  px_last  \
# 0  CHPOP Index  China Population Total         Total     中国 総人口  1409.67
#
#   indx_freq indx_units quote_units last_update_dt          long_comp_name
# 0    Yearly   Quantity    Millions     2023-12-31  China Population Total

# %%
T = ["CNNGPQ$"]
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=150)
d_from = date(2010, 1, 1)
df = BDH(T,d_from,d_to)
Plot("Excavato","CNNGPQ$","YoY")
df_BDP = BDP(T)
df_BDP
# Out:
#            index                         name security_name  \
# 0  CNNGPQ$ Index  China GDP Current Price NSA     GDP Qtrly
#
#                     name_kanji   px_last  indx_freq indx_units quote_units  \
# 0  China GDP Current Price NSA  34789.01  Quarterly      Value     Billion
#
#   crncy last_update_dt               long_comp_name
# 0   CNY     2023-12-31  China GDP Current Price NSA

# %%
T = ['MXCN','MXCN0TC','MXCN0CD','MXCN0CS','MXCN0EN','MXCN0FN','MXCN0RL','MXCN0HC','MXCN0MT','MXCN0IN','MXCN0UT']
d_to = workdays.workday(date.today(), days=0)
# d_from = d_to - relativedelta(months=150)
d_from = date(2010, 1, 1)
df = BDH(T,d_from,d_to)
Plot("Domestic CNY Households(billion, 預金総額)","MXCN","")
df_BDP = BDP(T)
df_BDP
# Out:
#             index                    name                   security_name  \
# 0      MXCN Index              MSCI CHINA                MSCI China Index
# 1   MXCN0TC Index        MSCI CN/COMM SVC  MSCI China Communication Servi
# 2   MXCN0CD Index     MSCI CHINA/CONS DIS  MSCI China Consumer Discretion
# 3   MXCN0CS Index     MSCI CHINA/CON STPL  MSCI China Consumer Staples In
# 4   MXCN0EN Index       MSCI CHINA/ENERGY   MSCI China Energy GICS Sector
# 5   MXCN0FN Index      MSCI CHINA/FINANCE     MSCI China Financials Index
# 6   MXCN0RL Index  MSCI CHINA/REAL ESTATE  MSCI China Real Estate GICS Le
# 7   MXCN0HC Index    MSCI CHINA/HLTH CARE    MSCI China Health Care Index
# 8   MXCN0MT Index     MSCI CHINA/MATERIAL  MSCI China Materials GICS Sect
# 9   MXCN0IN Index     MSCI CHINA/INDUSTRL    MSCI China Industrials Index
# 10  MXCN0UT Index      MSCI CHINA/UTILITY  MSCI China Utilities GICS Sect
#
#                       name_kanji  px_last indx_units crncy last_update_dt  \
# 0               MSCI China Index    52.11     Points   HKD     2024-01-27
# 1               MSCI CN/COMM SVC     90.6     Points   HKD     2024-01-27
# 2            MSCI CHINA/CONS DIS   143.42     Points   HKD     2024-01-27
# 3            MSCI CHINA/CON STPL  1001.38     Points   HKD     2024-01-27
# 4              MSCI CHINA/ENERGY   528.11     Points   HKD     2024-01-27
# 5    MSCI China Financials Index   324.48     Points   HKD     2024-01-27
# 6         MSCI CHINA/REAL ESTATE    407.8     Points   HKD     2024-01-27
# 7   MSCI China Health Care Index   138.63     Points   HKD     2024-01-27
# 8            MSCI CHINA/MATERIAL   656.17     Points   HKD     2024-01-27
# 9   MSCI China Industrials Index    85.22     Points   HKD     2024-01-27
# 10            MSCI CHINA/UTILITY   495.35     Points   HKD     2024-01-27
#
#                                long_comp_name
# 0                            MSCI China Index
# 1     MSCI China Communication Services Index
# 2     MSCI China Consumer Discretionary Index
# 3           MSCI China Consumer Staples Index
# 4         MSCI China Energy GICS Sector Index
# 5                 MSCI China Financials Index
# 6   MSCI China Real Estate GICS Level 1 Index
# 7                MSCI China Health Care Index
# 8      MSCI China Materials GICS Sector Index
# 9                MSCI China Industrials Index
# 10     MSCI China Utilities GICS Sector Index
