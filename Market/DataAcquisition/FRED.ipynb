# %%
import pandas_datareader.data as web
import matplotlib.pyplot as plt
start='2000/1/1'

# If a proxy is required
# import requests
# proxies = {
# 'http':'http://',
# 'https':'http://'
# }
# session = requests.Session()
# session.proxies.update(proxies)


# https://fred.stlouisfed.org/
# https://fred.stlouisfed.org/series/IHLIDXNEWUS

#Japanese site
# https://qiita.com/innovation1005/items/edcf78cbf89477b3b0a7
# https://qiita.com/Jake110ii/items/f4d9176fda9999d9676f

# %%
# New Job Postings on Indeed in the US and Canada
df = web.DataReader(['IHLIDXNEWUS','IHLIDXNEWCA'], 'fred', start)
# df = web.DataReader(['IHLIDXNEWUS','IHLIDXNEWCA'], 'fred', start, session=session) # If a proxy is required

display(df.tail())
df.plot(figsize=(6, 3))
# Out:
#             IHLIDXNEWUS  IHLIDXNEWCA
# DATE
# 2024-04-08       137.39        95.08
# 2024-04-09       136.07        98.48
# 2024-04-10       134.71       102.07
# 2024-04-11       133.07       105.13
# 2024-04-12       131.45       107.54
# <Axes: xlabel='DATE'>

# %%
# Job Openings: Total Nonfarm (JTSJOL)
df = web.DataReader(['JTSJOL'], 'fred', start)
# df = web.DataReader(['JTSJOL'], 'fred', start, session=session)  # If a proxy is required

display(df.tail())
df.plot(figsize=(6, 3))
# Out:
#             JTSJOL
# DATE
# 2023-10-01    8685
# 2023-11-01    8931
# 2023-12-01    8889
# 2024-01-01    8748
# 2024-02-01    8756
# <Axes: xlabel='DATE'>
