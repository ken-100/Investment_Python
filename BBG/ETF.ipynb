# %%
from xbbg import blp
def BDP(T):

    F = ['etf_undl_index_ticker','crncy','name_kanji','fund_management_co','fund_total_assets','fund_assets_usd','fund_expense_ratio','fund_total_exp']
    df = blp.bdp(tickers=T, flds=F).loc[T,:].reset_index(drop=False)
    df.rename(columns={'index': 'ticker'}, inplace=True)

    df = df.sort_values(by='fund_assets_usd', ascending=False)
    tmp = ['fund_total_assets','fund_assets_usd']
    df[tmp] = df[tmp].map('{:,.0f}'.format)

    return df

# %% [markdown]
# ### Topix

# %%
T0 = ['1306','1308','1305','1348','1475','1473','2524']
T = [x + ' JP Equity' for x in T0] 
df = BDP(T)
df
# Out:
#            ticker etf_undl_index_ticker crncy              name_kanji  \
# 0  1306 JP Equity                   TPX   JPY            NF・TOPIX ETF
# 1  1308 JP Equity                   TPX   JPY     上場ｲﾝﾃﾞｯｸｽﾌｧﾝﾄﾞTOPIX
# 2  1305 JP Equity                   TPX   JPY  iFreeETF TOPIX（年1回決算型)
# 3  1348 JP Equity                   TPX   JPY        MAXIS ﾄﾋﾟｯｸｽ上場投信
# 4  1475 JP Equity               TPXDDVD   JPY       iｼｪｱｰｽﾞ TOPIX ETF
# 5  1473 JP Equity                   TPX   JPY           Ｏｎｅ ＥＴＦ トピックス
# 6  2524 JP Equity                   TPX   JPY         NZAM 上場投信 TOPIX
#
#                               fund_management_co fund_total_assets  \
# 0                 Nomura Asset Management Co Ltd        22,414,910
# 1                  Nikko Asset Management Co Ltd        10,724,705
# 2                  Daiwa Asset Management Co Ltd        10,163,790
# 3         Mitsubishi UFJ Asset Management Co Ltd         3,242,908
# 4                         BlackRock Japan Co Ltd         1,708,634
# 5                    Asset Management One Co Ltd           562,851
# 6  Norinchukin Zenkyoren Asset Management Co Ltd           243,894
#
#   fund_assets_usd fund_expense_ratio fund_total_exp
# 0         156,245             0.0536         0.0536
# 1          74,757              0.053          0.053
# 2          70,848               0.06           0.06
# 3          22,605              0.078          0.078
# 4          11,910              0.045          0.045
# 5           3,923              0.078          0.078
# 6           1,700              0.075          0.075

# %%
T0 = ['ACWI US','ISAC LN','ACWD LN','2559 JP','1554 JP','VT US']
T = [x + ' Equity' for x in T0] 
df = BDP(T)
df
# Out:
#            ticker etf_undl_index_ticker crncy                    name_kanji  \
# 5    VT US Equity              TGPVA16U   USD   ﾊﾞﾝｶﾞｰﾄﾞ･ﾄｰﾀﾙ･ﾜｰﾙﾄﾞ･ｽﾄｯｸETF
# 0  ACWI US Equity              NDUEACWF   USD          iｼｪｱｰｽﾞMSCI ACWI ETF
# 1  ISAC LN Equity              NDUEACWF   USD  iｼｪｱｰｽﾞMSCI ACWI UCITS ETF U
# 2  ACWD LN Equity              NDUEACWF   USD      SPDR MSCI ACWI UCITS ETF
# 3  2559 JP Equity                  MXWD   JPY        MAXIS全世界株式(ｵｰﾙ･ｶﾝﾄﾘｰ)上
# 4  1554 JP Equity                 MXWDJ   JPY        上場ｲﾝﾃﾞｯｸｽﾌｧﾝﾄﾞ世界株式(MSC
#
#                         fund_management_co fund_total_assets fund_assets_usd  \
# 5                   Vanguard Group Inc/The            40,461          40,461
# 0                  BlackRock Fund Advisors            19,164          19,164
# 1   BlackRock Asset Management Ireland Ltd            16,216          16,216
# 2  State Street Global Advisors Europe Ltd             3,490           3,490
# 3   Mitsubishi UFJ Asset Management Co Ltd            55,205             385
# 4            Nikko Asset Management Co Ltd            11,804              82
#
#   fund_expense_ratio fund_total_exp
# 5               0.07           0.07
# 0               0.32           0.32
# 1                0.2            0.2
# 2               0.12           0.12
# 3              0.078          0.078
# 4               0.24           0.24

# %%
T0 = ['SPY','VTI','VOO','IVV','SPLG']
T = [x + ' US Equity' for x in T0] 
df = BDP(T)
df
# Out:
#            ticker etf_undl_index_ticker crncy                   name_kanji  \
# 0   SPY US Equity                  SPXT   USD          SPDR S&P500 ETFﾄﾗｽﾄ
# 2   VOO US Equity                  SPTR   USD            ﾊﾞﾝｶﾞｰﾄﾞS&P500ETF
# 3   IVV US Equity                  SPTR   USD            iｼｪｱｰｽﾞS&P500 ETF
# 1   VTI US Equity               CRSPTMT   USD  ﾊﾞﾝｶﾞｰﾄﾞ･ﾄｰﾀﾙ･ｽﾄｯｸ･ﾏｰｹｯﾄETF
# 4  SPLG US Equity                  SPXT   USD   SPDR Portfolio S&P 500 ETF
#
#           fund_management_co fund_total_assets fund_assets_usd  \
# 0  SSgA Funds Management Inc           572,097         572,097
# 2     Vanguard Group Inc/The           528,269         528,269
# 3    BlackRock Fund Advisors           506,964         506,964
# 1     Vanguard Group Inc/The           439,544         439,544
# 4  SSgA Funds Management Inc            45,698          45,698
#
#   fund_expense_ratio fund_total_exp
# 0             0.0945         0.0945
# 2               0.03           0.03
# 3               0.03           0.03
# 1               0.03           0.03
# 4               0.02           0.02

# %%
T0 = ['VEA US','VXUS US','VEU US','IXUS US', 'ACWX US', 'CWI US']
T = [x + ' Equity' for x in T0] 
df = BDP(T)
df
# Out:
#            ticker etf_undl_index_ticker crncy                    name_kanji  \
# 0   VEA US Equity               ACDXUSR   USD  ﾊﾞﾝｶﾞｰﾄﾞ FTSEﾃﾞｨﾍﾞﾛｯﾌﾟﾄﾞ･ﾏｰｹ
# 1  VXUS US Equity              TGPVAN17   USD  ﾊﾞﾝｶﾞｰﾄﾞ･ﾄｰﾀﾙ･ｲﾝﾀｰﾅｼｮﾅﾙ･ｽﾄｯｸ
# 2   VEU US Equity              AWXUSRUS   USD     ﾊﾞﾝｶﾞｰﾄﾞFTSEｵｰﾙﾜｰﾙﾄﾞ除米国ET
# 3  IXUS US Equity               M1WDUIM   USD  iｼｪｱｰｽﾞ･ｺｱMSCI ﾄｰﾀﾙ･ｲﾝﾀｰﾅｼｮﾅ
# 4  ACWX US Equity              NDUEACWZ   USD      iｼｪｱｰｽﾞMSCI ACWI(除米国)ETF
# 5   CWI US Equity                 M1WDU   USD           SPDR MSCI全世界株式(除く米国
#
#           fund_management_co fund_total_assets fund_assets_usd  \
# 0     Vanguard Group Inc/The           141,647         141,647
# 1     Vanguard Group Inc/The            77,372          77,372
# 2     Vanguard Group Inc/The            40,434          40,434
# 3    BlackRock Fund Advisors            38,996          38,996
# 4    BlackRock Fund Advisors             4,702           4,702
# 5  SSgA Funds Management Inc             1,640           1,640
#
#   fund_expense_ratio fund_total_exp
# 0               0.06           0.06
# 1               0.08           0.08
# 2               0.07           0.07
# 3               0.07           0.07
# 4               0.34           0.34
# 5                0.3            0.3

# %%
T0 = ['VWO US','IEMG US','EEM US','VFEA LN']
T = [x + ' Equity' for x in T0] 
df = BDP(T)
df
# Out:
#            ticker etf_undl_index_ticker crncy                    name_kanji  \
# 1  IEMG US Equity              MIMUEMRN   USD  iｼｪｱｰｽﾞ･ｺｱMSCIｴﾏｰｼﾞﾝｸﾞ･ﾏｰｹｯﾄ
# 0   VWO US Equity                FQEACR   USD  ﾊﾞﾝｶﾞｰﾄﾞFTSEｴﾏｰｼﾞﾝｸﾞ･ﾏｰｹｯﾂET
# 2   EEM US Equity               NDUEEGF   USD  iｼｪｱｰｽﾞMSCIｴﾏｰｼﾞﾝｸﾞ･ﾏｰｹｯﾄETF
# 3  VFEA LN Equity              TAWALENU   USD  ﾊﾞﾝｶﾞｰﾄﾞFTSEｴﾏｰｼﾞﾝｸﾞﾏｰｹｯﾂUCI
#
#            fund_management_co fund_total_assets fund_assets_usd  \
# 1     BlackRock Fund Advisors            81,128          81,128
# 0      Vanguard Group Inc/The            80,227          80,227
# 2     BlackRock Fund Advisors            17,930          17,930
# 3  Vanguard Group Ireland Ltd             3,016           3,016
#
#   fund_expense_ratio fund_total_exp
# 1               0.09           0.09
# 0               0.08           0.08
# 2                0.7            0.7
# 3               0.22           0.22

# %%
T0 = ['GOVT US','IGOV US','FLQA LN','USFR US','HGVU LN','1677 JP']
T = [x + ' Equity' for x in T0] 
df = BDP(T)
df
# Out:
#            ticker etf_undl_index_ticker crncy                    name_kanji  \
# 0  GOVT US Equity                IDCOTC   USD              iｼｪｱｰｽﾞ･ｺｱ米国債ETF
# 3  USFR US Equity              I37110US   USD  ｳｨｽﾞﾀﾞﾑﾂﾘｰ･ﾌﾞﾙｰﾑﾊﾞｰｸﾞ･ﾌﾛｰﾃｨﾝ
# 4  HGVU LN Equity                 SBWGU   USD  HSBC Global Funds ICAV - Glo
# 1  IGOV US Equity              CFIIWDCS   USD                iｼｪｱｰｽﾞ世界国債ETF
# 5  1677 JP Equity              SBWJNJYU   JPY        上場ｲﾝﾃﾞｯｸｽﾌｧﾝﾄﾞ海外債券(FTS
# 6  2561 JP Equity               CFIIJYL   JPY          i ｼｪｱｰｽﾞ･ｺｱ 日本国債 ETF
# 2  FLQA LN Equity              AWAPXJCN   USD   Franklin FTSE Asia ex China
#
#                                fund_management_co fund_total_assets  \
# 0                         BlackRock Fund Advisors            27,867
# 3                 WisdomTree Asset Management Inc            17,113
# 4  HSBC Investment Funds Luxembourg SA/Luxembourg             7,475
# 1                         BlackRock Fund Advisors               525
# 5                   Nikko Asset Management Co Ltd            31,376
# 6                          BlackRock Japan Co Ltd            29,329
# 2  Franklin Templeton International Services Sarl                78
#
#   fund_assets_usd fund_expense_ratio fund_total_exp
# 0          27,867               0.05           0.05
# 3          17,113               0.15           0.15
# 4           7,475               0.22           0.22
# 1             525               0.35           0.35
# 5             219               0.25           0.25
# 6             204               0.06           0.06
# 2              78               0.14           0.14
